# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from implementations import *
from Data_cleaning import *
from helpers import *
from exploratory_data_analysis import *

# %%
x_train, x_test, y_train, train_ids, test_ids = load_csv_data("data\dataset\dataset")

# %%
X = x_train
y = (y_train + 1) / 2

# %%
nan_number, nan_pctg = nan_count(X, plot=True)

# %%
print(nan_number)
# Out:
# [     0      0      0      0      0      0      0      0      0 139415
#  139415 328103 139416 139415 328103 139433 139524 139525 188720 188720
#  188721 188720 327334 188719 189287 192544      2      1      0 159860
#       0      0      1      1      1 196334      0  43801  43801      0
#       0 284153      1      0      0      1      0      0      5 285915
#       0      0      0      0 139415 318245 139415      1      0      3
#    2471   3207   3946   4407 279663   6933   7743   8293   8728   9149
#    9432   9862  10541 191379 282510 237369  11007  11765 170906 171212
#  171522  20738  21567  22468  23149  23759  24502  26205 107829 109141
#  109407 109690 181261 181400  28647 226907 227043 227197 229088  29911
#   30600 186763 186001  31022  32080 243418 243561 266689 266689 306425
#  306426 306428 306429 306429 306629 306429 306430 306430 247299 310302
#  310320 310346 310367 310392 310403 310450 265347 325762 325769 325769
# ...

# %%
cat_mask, num_mask = detect_categorical_features(X, max_unique=10)

# %%
print(np.sum(cat_mask), 321 - np.sum(cat_mask))
# Out:
# 219 102

# %%
stats = summarize_basic(X, cat_mask)

# %%
show_feature_stats(stats, 1)
# Out:
# Feature 1
#   Mean:   6.3607
#   Std:    3.4873
#   Min:    1.0000
#   Max:    12.0000
#   Median: 6.0000
#   Mode:   nan

# %%
plot_feature_distribution(X, cat_mask, feature_index=0)

# %%
cov_num = compute_covariance_numerical(X, num_mask, plot=True)

# %%
print(cov_num)
# Out:
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]

# %%
categorical_relationship(X, cat_mask, plot=True)
numeric_categorical_relationship(X, num_mask, cat_mask, plot=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 categorical_relationship(X, cat_mask, plot=True)
#       2 numeric_categorical_relationship(X, num_mask, cat_mask, plot=True)
#
# File ~\Documents\GitHub\ML_proj1\project1\exploratory_data_analysis.py:255, in categorical_relationship(X, cat_mask, plot)
#     252     continue
#     254 vals_i, idx_i = np.unique(xi, return_inverse=True)
# --> 255 vals_j, idx_j = np.unique(xj, return_inverse=True)
#     256 table = np.zeros((len(vals_i), len(vals_j)))
#     258 for a, b in zip(idx_i, idx_j):
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\_arraysetops_impl.py:294, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan, sorted)
#     292 ar = np.asanyarray(ar)
#     293 if axis is None:
# --> 294     ret = _unique1d(ar, return_index, return_inverse, return_counts,
# ...

# %%
corr, types = feature_target_correlation(X, y, cat_mask)

# %%
print(np.sum(corr > 0.2))
# Out:
# 12

# %%
outlier_mask, outlier_counts = detect_outliers(X, num_mask, threshold=1.5, plot=True)
summarize_outliers(outlier_mask, num_mask, plot=True)
# Out:
# array([ 0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#         3.27548113,  3.27548113,  2.07993661,  0.69453121, 12.67770887,
#        20.31755223,  0.        ,  0.        ,  0.        ,  1.03372088,
#         0.        ,  7.27596873, 18.58137657,  0.        ,  6.40498575,
#        11.49130693,  3.75942828,  0.        ,  1.63347403, 17.63603395,
#         8.54252061, 15.02217075,  1.85624819,  0.        ,  0.64485654,
#         6.62471239,  0.        ,  0.50345132,  5.58154418,  0.        ,
#         0.58939156,  7.03186189,  0.15390007,  0.        ,  0.93863806,
#         1.15623143,  1.28300852,  1.24369543,  1.06053911,  0.        ,
#         0.03504655,  0.24989715,  1.83217273,  0.        ,  0.        ,
#         0.        ,  0.0347418 ,  0.96789431,  2.29570146,  0.        ,
#         0.        ,  0.        ,  0.        ,  0.        ,  0.83532692,
#         0.72287321,  0.59548661,  0.        , 15.23884986,  2.0086245 ,
# ...

# %%
feature_diff(X, y, cat_mask, num_mask, top_k=10, plot=True)
# Out:
# C:\Users\Jan\Documents\GitHub\ML_proj1\project1\exploratory_data_analysis.py:592: RuntimeWarning: Mean of empty slice
#   mean_0 = np.nanmean(X_cat[y == 0], axis=0)
# === Top Numerical Features by Mean Difference ===
# Feature 2: 66908.6314
# Feature 105: 65636.3380
# Feature 101: 3653.9833
# Feature 219: 3045.0649
# Feature 8: 732.6615
# Feature 7: 732.6615
# Feature 264: 704.0066
# Feature 62: 190.9600
# Feature 229: 167.0631
# Feature 77: 109.2724
#
# === Top Categorical Features by Mean Difference ===
# Feature 147: 12.0109
# Feature 231: 2.6271
# Feature 6: 2.2280
# Feature 58: 2.0961
# Feature 168: 1.7563
# Feature 216: 1.4029
# Feature 130: 1.1949
# Feature 249: 1.1326
# Feature 223: 0.9656
# Feature 26: 0.9596
# (array([3.18001113e-01, 8.19189791e-02, 6.69086314e+04, 7.40921950e-02,
#         7.18355592e-01, 7.32661472e+02, 7.32661472e+02, 1.58376452e-01,
#         4.46136801e-02, 1.13491837e-01, 1.82744962e-01, 1.27163039e+01,
# ...
